# %%
import itertools
import pandas as pd
import networkx as nx
from ipysigma import Sigma

# If needed, enable ipysigma extension
#!jupyter labextension enable ipysigma
#!jupyter labextension enable ipysigma user
#!jupyter labextension enable ipysigma sys-prefix

# %%
# Lire le fichier
df = pd.read_csv("data.csv", index_col=0)
df.head()
# Out:
#        NOM   CAM[A]     CAM[B]     CAM[C]     CAM[D]     CAM[E]     CAM[F]  \
# 0  5803360  3693620  8722835.0        NaN        NaN        NaN        NaN
# 1  4210690  2699038  2773067.0  7829617.0        NaN        NaN        NaN
# 2  8609491  3693620  8722835.0        NaN        NaN        NaN        NaN
# 3  2773067  2699038  7829617.0  4210690.0  5632126.0        NaN        NaN
# 4  5876752  2777709  3830485.0  3677094.0  3417362.0  6581735.0  2193432.0
#
#       CAM[G]    CAM[H]  CAM[I]  ...  CAM[Q]  CAM[R]  CAM[S]  CAM[T]  CAM[U]  \
# 0        NaN       NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 1        NaN       NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 2        NaN       NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 3        NaN       NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# 4  6021452.0  279883.0     NaN  ...     NaN     NaN     NaN     NaN     NaN
#
#    CAM[V]  CAM[W]  CAM[X]  CAM[Y]  CAM[Z]
# 0     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN
#
# [5 rows x 27 columns]

# %%
# Construire le réseau
repondants = list(df["NOM"])
data = df.apply(lambda x : [j for j in list(x) if str(j) != "nan" and j in repondants], axis = 1)

reseau = nx.Graph()
for line in data:
    for n in line:
        if reseau.has_node(n):
            reseau.nodes[n]["weight"] +=1
        else:
            reseau.add_node(n,weight=1)
    for p in itertools.combinations(line,2):
        if reseau.has_edge(p[0],p[1]):
            reseau.edges[p]["weight"] += 1
        else:
            reseau.add_edge(p[0],p[1], weight=1)
            
nx.write_graphml(reseau, "reseau.graphml")
print(reseau)
# Out:
# Graph with 21 nodes and 109 edges

# %%
# Visualiser le réseau
Sigma(reseau, node_size = "weight")
# Out:
# Sigma(nx.Graph with 21 nodes and 109 edges)
